# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup

# %%
ALL_BRAWLERS_URL = 'https://brawlstars.fandom.com/wiki/Category:Brawlers'
response = requests.get(ALL_BRAWLERS_URL)
soup = BeautifulSoup(response.content, 'html.parser')
brawlers = soup.find_all('a', {'class':'category-page__member-link'})

# %%
names_lst = []
for brawler in brawlers:
    name = brawler.text
    if 'Category:' in name or 'User blog' in name:
        continue
    names_lst.append(name)

# %%
brawlerDict = {}
for name in names_lst:
    BRAWLER_URL = f'https://brawlstars.fandom.com/wiki/{name}'
    response = requests.get(BRAWLER_URL)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Info
    brawlerInfo = {}
    data_sources = ['Rarity', 'Class','MovementSpeed','AttackRange','AttackBullets','Reload','AttackSuperCharge','AttackSpeed','AttackWidth','SuperRange','SuperSuperCharge','SuperSpeed']
    for data_source in data_sources:
        try:
            raw_value = soup.find_all('div', {'data-source':f'{data_source}'})[0].find('div', {'class': 'pi-data-value'}).get_text(separator=', ', strip = True)#.text.split('<br>')[0]#.strip()
            cleaned_value = re.split('\(|%|°|, |º|second', raw_value)[0].strip()
            if '-' in cleaned_value:
                cleaned_value = abs(float(cleaned_value.split('-')[0]) - float(cleaned_value.split('-')[1])) / 2
            brawlerInfo[f'{data_source}'] = cleaned_value
        except:
            brawlerInfo[f'{data_source}'] = float('nan')
    if name == 'Gray': brawlerInfo['SuperSpeed'] = float('nan')
    
    # Health
    healthDict = {}
    health = soup.find_all('td', {'data-source':'Health'})[1:]
    for i in range(len(health)):
        if i%2 == 0:
            healthDict[f'{health[i].text.strip()}'] = health[i+1].text.strip()
    brawlerInfo['Health'] = healthDict
    
    # Attack
    attackDict = {}
    attack = soup.find_all('td', {'data-source':'Attack'})[1:]
    for i in range(len(attack)):
        if i%2 == 0:
            attackDict[f'{attack[i].text.strip()}'] = attack[i+1].text.strip()
    brawlerInfo['Attack'] = attackDict
    
    brawlerDict[f'{name.upper()}'] = brawlerInfo
    print(name)
# Out:
# 8-Bit
# Amber
# Ash
# Barley
# Bea
# Belle
# Bibi
# Bo
# Bonnie
# Brock
# Bull
# Buster
# Buzz
# Byron
# Carl
# Chester
# Colette
# Colt
# Crow
# Darryl
# Dynamike
# Edgar
# El Primo
# Emz
# Eve
# Fang
# Frank
# Gale
# Gene
# Gray
# Griff
# Grom
# Gus
# Jacky
# Janet
# Jessie
# Leon
# Lola
# Lou
# Mandy
# Max
# Meg
# Mortis
# Mr. P
# Nani
# Nita
# Otis
# Pam
# Penny
# Piper
# Poco
# R-T
# Rico
# Rosa
# Ruffs
# Sam
# Sandy
# Shelly
# Spike
# Sprout
# Squeak
# Stu
# Surge
# Tara
# Tick
# Willow

# %%
brawlerDict
# Out:
# {'8-BIT': {'Rarity': 'Super Rare',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '580',
#   'AttackRange': '10',
#   'AttackBullets': '6',
#   'Reload': '1.5',
#   'AttackSuperCharge': '8.48',
#   'AttackSpeed': '4500',
#   'AttackWidth': '0.33',
#   'SuperRange': '5',
#   'SuperSuperCharge': nan,
#   'SuperSpeed': '1196',
#   'Health': {'1': '4800',
#    '2': '5040',
#    '3': '5280',
#    '4': '5520',
#    '5': '5760',
#    '6': '6000',
#    '7': '6240',
#    '8': '6480',
#    '9': '6720',
#    '10': '6960',
#    '11': '7200'},
#   'Attack': {'1': '320',
#    '2': '336',
#    '3': '352',
#    '4': '368',
#    '5': '384',
#    '6': '400',
#    '7': '416',
#    '8': '432',
#    '9': '448',
#    '10': '464',
#    '11': '480'}},
#  'AMBER': {'Rarity': 'Legendary',
#   'Class': 'Controller',
#   'MovementSpeed': '720',
#   'AttackRange': '8.33',
#   'AttackBullets': '40',
#   'Reload': '0.22',
#   'AttackSuperCharge': '4.55',
#   'AttackSpeed': '3500',
#   'AttackWidth': '1.33',
#   'SuperRange': '7.33',
#   'SuperSuperCharge': '6.36',
#   'SuperSpeed': '1750',
#   'Health': {'1': '3200',
#    '2': '3360',
#    '3': '3520',
#    '4': '3680',
#    '5': '3840',
#    '6': '4000',
#    '7': '4160',
#    '8': '4320',
#    '9': '4480',
#    '10': '4640',
#    '11': '4800'},
#   'Attack': {'1': '200',
#    '2': '210',
#    '3': '220',
#    '4': '230',
#    '5': '240',
#    '6': '250',
#    '7': '260',
#    '8': '270',
#    '9': '280',
#    '10': '290',
#    '11': '300'}},
#  'ASH': {'Rarity': 'Chromatic',
#   'Class': 'Tank',
#   'MovementSpeed': '720',
#   'AttackRange': '4.67',
#   'AttackBullets': nan,
#   'Reload': '1.4',
#   'AttackSuperCharge': '16.8',
#   'AttackSpeed': '5000',
#   'AttackWidth': '1.67',
#   'SuperRange': '5',
#   'SuperSuperCharge': '3.75',
#   'SuperSpeed': '1196',
#   'Health': {'1': '5400',
#    '2': '5670',
#    '3': '5940',
#    '4': '6210',
#    '5': '6480',
#    '6': '6750',
#    '7': '7020',
#    '8': '7290',
#    '9': '7560',
#    '10': '7830',
#    '11': '8100'},
#   'Attack': {'1': '800',
#    '2': '840',
#    '3': '880',
#    '4': '920',
#    '5': '960',
#    '6': '1000',
#    '7': '1040',
#    '8': '1080',
#    '9': '1120',
#    '10': '1160',
#    '11': '1200'}},
#  'BARLEY': {'Rarity': 'Rare',
#   'Class': 'Artillery',
#   'MovementSpeed': '720',
#   'AttackRange': '7.33',
#   'AttackBullets': nan,
#   'Reload': '2',
#   'AttackSuperCharge': '17.5',
#   'AttackSpeed': '1750',
#   'AttackWidth': nan,
#   'SuperRange': '9.33',
#   'SuperSuperCharge': '12.58',
#   'SuperSpeed': '1504',
#   'Health': {'1': '2400',
#    '2': '2520',
#    '3': '2640',
#    '4': '2760',
#    '5': '2880',
#    '6': '3000',
#    '7': '3120',
#    '8': '3240',
#    '9': '3360',
#    '10': '3480',
#    '11': '3600'},
#   'Attack': {'1': '760',
#    '2': '798',
#    '3': '836',
#    '4': '874',
#    '5': '912',
#    '6': '950',
#    '7': '988',
#    '8': '1026',
#    '9': '1064',
#    '10': '1102',
#    '11': '1140'}},
#  'BEA': {'Rarity': 'Epic',
#   'Class': 'Marksman',
#   'MovementSpeed': '720',
#   'AttackRange': '10',
#   'AttackBullets': nan,
#   'Reload': '0.9',
#   'AttackSuperCharge': '35.6',
#   'AttackSpeed': '3255',
#   'AttackWidth': '1',
#   'SuperRange': '9',
#   'SuperSuperCharge': '2.5',
#   'SuperSpeed': '2500',
#   'Health': {'1': '2400',
#    '2': '2520',
#    '3': '2640',
#    '4': '2760',
#    '5': '2880',
#    '6': '3000',
#    '7': '3120',
#    '8': '3240',
#    '9': '3360',
#    '10': '3480',
#    '11': '3600'},
#   'Attack': {'1': '800',
#    '2': '840',
#    '3': '880',
#    '4': '920',
#    '5': '960',
#    '6': '1000',
#    '7': '1040',
#    '8': '1080',
#    '9': '1120',
#    '10': '1160',
#    '11': '1200'}},
#  'BELLE': {'Rarity': 'Chromatic',
#   'Class': 'Marksman',
#   'MovementSpeed': '720',
#   'AttackRange': '10',
#   'AttackBullets': nan,
#   'Reload': '1.4',
#   'AttackSuperCharge': '21.84',
#   'AttackSpeed': '4000',
#   'AttackWidth': '0.67',
#   'SuperRange': '10.67',
#   'SuperSuperCharge': '25',
#   'SuperSpeed': '4000',
#   'Health': {'1': '2600',
#    '2': '2730',
#    '3': '2860',
#    '4': '2990',
#    '5': '3120',
#    '6': '3250',
#    '7': '3380',
#    '8': '3510',
#    '9': '3640',
#    '10': '3770',
#    '11': '3900'},
#   'Attack': {'1': '1040',
#    '2': '1092',
#    '3': '1144',
#    '4': '1196',
#    '5': '1248',
#    '6': '1300',
#    '7': '1352',
#    '8': '1404',
#    '9': '1456',
#    '10': '1508',
#    '11': '1560'}},
#  'BIBI': {'Rarity': 'Epic',
#   'Class': 'Tank',
#   'MovementSpeed': '820',
#   'AttackRange': '3.67',
#   'AttackBullets': nan,
#   'Reload': '0.8',
#   'AttackSuperCharge': '35.75',
#   'AttackSpeed': nan,
#   'AttackWidth': nan,
#   'SuperRange': '40',
#   'SuperSuperCharge': '25.2',
#   'SuperSpeed': '3000',
#   'Health': {'1': '4600',
#    '2': '4830',
#    '3': '5060',
#    '4': '5290',
#    '5': '5520',
#    '6': '5750',
#    '7': '5980',
#    '8': '6210',
#    '9': '6440',
#    '10': '6670',
#    '11': '6900'},
#   'Attack': {'1': '1400',
#    '2': '1470',
#    '3': '1540',
#    '4': '1610',
#    '5': '1680',
#    '6': '1750',
#    '7': '1820',
#    '8': '1890',
#    '9': '1960',
#    '10': '2030',
#    '11': '2100'}},
#  'BO': {'Rarity': 'Epic',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '720',
#   'AttackRange': '8.67',
#   'AttackBullets': '3',
#   'Reload': '1.7',
#   'AttackSuperCharge': '12',
#   'AttackSpeed': '2800',
#   'AttackWidth': '0.47',
#   'SuperRange': '8.67',
#   'SuperSuperCharge': '33.48',
#   'SuperSpeed': '2391',
#   'Health': {'1': '3600',
#    '2': '3780',
#    '3': '3960',
#    '4': '4140',
#    '5': '4320',
#    '6': '4500',
#    '7': '4680',
#    '8': '4860',
#    '9': '5040',
#    '10': '5220',
#    '11': '5400'},
#   'Attack': {'1': '600',
#    '2': '630',
#    '3': '660',
#    '4': '690',
#    '5': '720',
#    '6': '750',
#    '7': '780',
#    '8': '810',
#    '9': '840',
#    '10': '870',
#    '11': '900'}},
#  'BONNIE': {'Rarity': 'Epic',
#   'Class': 'Marksman',
#   'MovementSpeed': '620',
#   'AttackRange': '9',
#   'AttackBullets': '1',
#   'Reload': '1',
#   'AttackSuperCharge': '25',
#   'AttackSpeed': '4000',
#   'AttackWidth': '1',
#   'SuperRange': '7',
#   'SuperSuperCharge': nan,
#   'SuperSpeed': '3000',
#   'Health': {'1': '4800',
#    '2': '5040',
#    '3': '5280',
#    '4': '5520',
#    '5': '5760',
#    '6': '6000',
#    '7': '6240',
#    '8': '6480',
#    '9': '6720',
#    '10': '6960',
#    '11': '7200'},
#   'Attack': {'1': '1000',
#    '2': '1050',
#    '3': '1100',
#    '4': '1150',
#    '5': '1200',
#    '6': '1250',
#    '7': '1300',
#    '8': '1350',
#    '9': '1400',
#    '10': '1450',
#    '11': '1500'}},
#  'BROCK': {'Rarity': 'Rare',
#   'Class': 'Marksman',
#   'MovementSpeed': '720',
#   'AttackRange': '9',
#   'AttackBullets': nan,
#   'Reload': '2.1',
#   'AttackSuperCharge': '26.1',
#   'AttackSpeed': '2700',
#   'AttackWidth': '0.67',
#   'SuperRange': '8.33',
#   'SuperSuperCharge': '20.8',
#   'SuperSpeed': '870',
#   'Health': {'1': '2400',
#    '2': '2520',
#    '3': '2640',
#    '4': '2760',
#    '5': '2880',
#    '6': '3000',
#    '7': '3120',
#    '8': '3240',
#    '9': '3360',
#    '10': '3480',
#    '11': '3600'},
#   'Attack': {'1': '1160',
#    '2': '1218',
#    '3': '1276',
#    '4': '1334',
#    '5': '1392',
#    '6': '1450',
#    '7': '1508',
#    '8': '1566',
#    '9': '1624',
#    '10': '1682',
#    '11': '1740'}},
#  'BULL': {'Rarity': 'Rare',
#   'Class': 'Tank',
#   'MovementSpeed': '770',
#   'AttackRange': '5.33',
#   'AttackBullets': '5',
#   'Reload': '1.6',
#   'AttackSuperCharge': '10',
#   'AttackSpeed': '2853',
#   'AttackWidth': nan,
#   'SuperRange': '11',
#   'SuperSuperCharge': '30',
#   'SuperSpeed': nan,
#   'Health': {'1': '5000',
#    '2': '5250',
#    '3': '5500',
#    '4': '5750',
#    '5': '6000',
#    '6': '6250',
#    '7': '6500',
#    '8': '6750',
#    '9': '7000',
#    '10': '7250',
#    '11': '7500'},
#   'Attack': {'1': '400',
#    '2': '420',
#    '3': '440',
#    '4': '460',
#    '5': '480',
#    '6': '500',
#    '7': '520',
#    '8': '540',
#    '9': '560',
#    '10': '580',
#    '11': '600'}},
#  'BUSTER': {'Rarity': 'Chromatic',
#   'Class': 'Tank',
#   'MovementSpeed': '770',
#   'AttackRange': '5.33',
#   'AttackBullets': nan,
#   'Reload': '1.8',
#   'AttackSuperCharge': 8.25,
#   'AttackSpeed': '4200',
#   'AttackWidth': nan,
#   'SuperRange': '3',
#   'SuperSuperCharge': nan,
#   'SuperSpeed': '3200',
#   'Health': {'1': '4800',
#    '2': '5040',
#    '3': '5280',
#    '4': '5520',
#    '5': '5760',
#    '6': '6000',
#    '7': '6240',
#    '8': '6480',
#    '9': '6720',
#    '10': '6960',
#    '11': '7200'},
#   'Attack': {'1': '1320',
#    '2': '1386',
#    '3': '1452',
#    '4': '1518',
#    '5': '1584',
#    '6': '1650',
#    '7': '1716',
#    '8': '1782',
#    '9': '1848',
#    '10': '1914',
#    '11': '1980'}},
#  'BUZZ': {'Rarity': 'Chromatic',
#   'Class': 'Assassin',
#   'MovementSpeed': '770',
#   'AttackRange': '2.67',
#   'AttackBullets': '5',
#   'Reload': '1',
#   'AttackSuperCharge': '10.08',
#   'AttackSpeed': '4000',
#   'AttackWidth': '1',
#   'SuperRange': '10',
#   'SuperSuperCharge': nan,
#   'SuperSpeed': '3500',
#   'Health': {'1': '4400',
#    '2': '4620',
#    '3': '4840',
#    '4': '5060',
#    '5': '5280',
#    '6': '5500',
#    '7': '5720',
#    '8': '5940',
#    '9': '6160',
#    '10': '6380',
#    '11': '6600'},
#   'Attack': {'1': '420',
#    '2': '441',
#    '3': '462',
#    '4': '483',
#    '5': '504',
#    '6': '525',
#    '7': '546',
#    '8': '567',
#    '9': '588',
#    '10': '609',
#    '11': '630'}},
#  'BYRON': {'Rarity': 'Mythic',
#   'Class': 'Support',
#   'MovementSpeed': '720',
#   'AttackRange': '10',
#   'AttackBullets': nan,
#   'Reload': '1.45',
#   'AttackSuperCharge': '9',
#   'AttackSpeed': '4000',
#   'AttackWidth': '1',
#   'SuperRange': '7.33',
#   'SuperSuperCharge': '22.875',
#   'SuperSpeed': '2000',
#   'Health': {'1': '2400',
#    '2': '2520',
#    '3': '2640',
#    '4': '2760',
#    '5': '2880',
#    '6': '3000',
#    '7': '3120',
#    '8': '3240',
#    '9': '3360',
#    '10': '3480',
#    '11': '3600'},
#   'Attack': {'1': '340',
#    '2': '357',
#    '3': '374',
#    '4': '391',
#    '5': '408',
#    '6': '425',
#    '7': '442',
#    '8': '459',
#    '9': '476',
#    '10': '493',
#    '11': '510'}},
#  'CARL': {'Rarity': 'Super Rare',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '720',
#   'AttackRange': '8.33',
#   'AttackBullets': nan,
#   'Reload': nan,
#   'AttackSuperCharge': '16.83',
#   'AttackSpeed': '3000',
#   'AttackWidth': '1.67',
#   'SuperRange': '2.33',
#   'SuperSuperCharge': '6.3',
#   'SuperSpeed': nan,
#   'Health': {'1': '4000',
#    '2': '4200',
#    '3': '4400',
#    '4': '4600',
#    '5': '4800',
#    '6': '5000',
#    '7': '5200',
#    '8': '5400',
#    '9': '5600',
#    '10': '5800',
#    '11': '6000'},
#   'Attack': {'1': '660',
#    '2': '693',
#    '3': '726',
#    '4': '759',
#    '5': '792',
#    '6': '825',
#    '7': '858',
#    '8': '891',
#    '9': '924',
#    '10': '957',
#    '11': '990'}},
#  'CHESTER': {'Rarity': 'Legendary',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '770',
#   'AttackRange': '8.33',
#   'AttackBullets': '1',
#   'Reload': '1.9',
#   'AttackSuperCharge': '16.5',
#   'AttackSpeed': nan,
#   'AttackWidth': nan,
#   'SuperRange': '8.33',
#   'SuperSuperCharge': '49.5',
#   'SuperSpeed': '800',
#   'Health': {'1': '3300',
#    '2': '3465',
#    '3': '3630',
#    '4': '3795',
#    '5': '3960',
#    '6': '4125',
#    '7': '4290',
#    '8': '4455',
#    '9': '4620',
#    '10': '4785',
#    '11': '4950'},
#   'Attack': {'1': '640',
#    '2': '672',
#    '3': '704',
#    '4': '736',
#    '5': '768',
#    '6': '800',
#    '7': '832',
#    '8': '864',
#    '9': '896',
#    '10': '928',
#    '11': '960'}},
#  'COLETTE': {'Rarity': 'Chromatic',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '720',
#   'AttackRange': '8.67',
#   'AttackBullets': nan,
#   'Reload': '1.6',
#   'AttackSuperCharge': '25',
#   'AttackSpeed': '4000',
#   'AttackWidth': '1',
#   'SuperRange': '11',
#   'SuperSuperCharge': '25',
#   'SuperSpeed': nan,
#   'Health': {'1': '3400',
#    '2': '3570',
#    '3': '3740',
#    '4': '3910',
#    '5': '4080',
#    '6': '4250',
#    '7': '4420',
#    '8': '4590',
#    '9': '4760',
#    '10': '4930',
#    '11': '5100'},
#   'Attack': {'1': '500',
#    '2': '525',
#    '3': '550',
#    '4': '575',
#    '5': '600',
#    '6': '625',
#    '7': '650',
#    '8': '675',
#    '9': '700',
#    '10': '725',
#    '11': '750'}},
#  'COLT': {'Rarity': 'Rare',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '720',
#   'AttackRange': '9',
#   'AttackBullets': '6',
#   'Reload': '1.7',
#   'AttackSuperCharge': '8.37',
#   'AttackSpeed': '4000',
#   'AttackWidth': '0.33',
#   'SuperRange': '11',
#   'SuperSuperCharge': '6.96',
#   'SuperSpeed': '4891',
#   'Health': {'1': '2800',
#    '2': '2940',
#    '3': '3080',
#    '4': '3220',
#    '5': '3360',
#    '6': '3500',
#    '7': '3640',
#    '8': '3780',
#    '9': '3920',
#    '10': '4060',
#    '11': '4200'},
#   'Attack': {'1': '360',
#    '2': '378',
#    '3': '396',
#    '4': '414',
#    '5': '432',
#    '6': '450',
#    '7': '468',
#    '8': '486',
#    '9': '504',
#    '10': '522',
#    '11': '540'}},
#  'CROW': {'Rarity': 'Legendary',
#   'Class': 'Assassin',
#   'MovementSpeed': '820',
#   'AttackRange': '8.67',
#   'AttackBullets': '3',
#   'Reload': '1.4',
#   'AttackSuperCharge': '7.12',
#   'AttackSpeed': '3261',
#   'AttackWidth': '0.33',
#   'SuperRange': '8.67',
#   'SuperSuperCharge': '6',
#   'SuperSpeed': '3261',
#   'Health': {'1': '2400',
#    '2': '2520',
#    '3': '2640',
#    '4': '2760',
#    '5': '2880',
#    '6': '3000',
#    '7': '3120',
#    '8': '3240',
#    '9': '3360',
#    '10': '3480',
#    '11': '3600'},
#   'Attack': {'1': '320',
#    '2': '336',
#    '3': '352',
#    '4': '368',
#    '5': '384',
#    '6': '400',
#    '7': '416',
#    '8': '432',
#    '9': '448',
#    '10': '464',
#    '11': '480'}},
#  'DARRYL': {'Rarity': 'Super Rare',
#   'Class': 'Tank',
#   'MovementSpeed': '770',
#   'AttackRange': '6',
#   'AttackBullets': '10',
#   'Reload': '1.8',
#   'AttackSuperCharge': '7.02',
#   'AttackSpeed': '3044',
#   'AttackWidth': nan,
#   'SuperRange': '7',
#   'SuperSuperCharge': '12',
#   'SuperSpeed': nan,
#   'Health': {'1': '5300',
#    '2': '5565',
#    '3': '5830',
#    '4': '6095',
#    '5': '6360',
#    '6': '6625',
#    '7': '6890',
#    '8': '7155',
#    '9': '7420',
#    '10': '7685',
#    '11': '7950'},
#   'Attack': {'1': '240',
#    '2': '252',
#    '3': '264',
#    '4': '276',
#    '5': '288',
#    '6': '300',
#    '7': '312',
#    '8': '324',
#    '9': '336',
#    '10': '348',
#    '11': '360'}},
#  'DYNAMIKE': {'Rarity': 'Super Rare',
#   'Class': 'Artillery',
#   'MovementSpeed': '770',
#   'AttackRange': '7.33',
#   'AttackBullets': '2',
#   'Reload': '1.6',
#   'AttackSuperCharge': '25',
#   'AttackSpeed': '1900',
#   'AttackWidth': nan,
#   'SuperRange': '7.33',
#   'SuperSuperCharge': '50.05',
#   'SuperSpeed': '1600',
#   'Health': {'1': '2800',
#    '2': '2940',
#    '3': '3080',
#    '4': '3220',
#    '5': '3360',
#    '6': '3500',
#    '7': '3640',
#    '8': '3780',
#    '9': '3920',
#    '10': '4060',
#    '11': '4200'},
#   'Attack': {'1': '800',
#    '2': '840',
#    '3': '880',
#    '4': '920',
#    '5': '960',
#    '6': '1000',
#    '7': '1040',
#    '8': '1080',
#    '9': '1120',
#    '10': '1160',
#    '11': '1200'}},
#  'EDGAR': {'Rarity': 'Epic',
#   'Class': 'Assassin',
#   'MovementSpeed': '820',
#   'AttackRange': '2',
#   'AttackBullets': '2',
#   'Reload': '0.7',
#   'AttackSuperCharge': '8.37',
#   'AttackSpeed': '3500',
#   'AttackWidth': '2',
#   'SuperRange': '6.67',
#   'SuperSuperCharge': nan,
#   'SuperSpeed': nan,
#   'Health': {'1': '2800',
#    '2': '2940',
#    '3': '3080',
#    '4': '3220',
#    '5': '3360',
#    '6': '3500',
#    '7': '3640',
#    '8': '3780',
#    '9': '3920',
#    '10': '4060',
#    '11': '4200'},
#   'Attack': {'1': '540',
#    '2': '567',
#    '3': '594',
#    '4': '621',
#    '5': '648',
#    '6': '675',
#    '7': '702',
#    '8': '729',
#    '9': '756',
#    '10': '783',
#    '11': '810'}},
#  'EL PRIMO': {'Rarity': 'Rare',
#   'Class': 'Tank',
#   'MovementSpeed': '770',
#   'AttackRange': '3',
#   'AttackBullets': '4',
#   'Reload': '0.8',
#   'AttackSuperCharge': '8.3',
#   'AttackSpeed': '3261',
#   'AttackWidth': '1',
#   'SuperRange': '9',
#   'SuperSuperCharge': '25',
#   'SuperSpeed': nan,
#   'Health': {'1': '6000',
#    '2': '6300',
#    '3': '6600',
#    '4': '6900',
#    '5': '7200',
#    '6': '7500',
#    '7': '7800',
#    '8': '8100',
#    '9': '8400',
#    '10': '8700',
#    '11': '9000'},
#   'Attack': {'1': '360',
#    '2': '378',
#    '3': '396',
#    '4': '414',
#    '5': '432',
#    '6': '450',
#    '7': '468',
#    '8': '486',
#    '9': '504',
#    '10': '522',
#    '11': '540'}},
#  'EMZ': {'Rarity': 'Epic',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '720',
#   'AttackRange': '6.67',
#   'AttackBullets': nan,
#   'Reload': '2',
#   'AttackSuperCharge': '11.18',
#   'AttackSpeed': '1500',
#   'AttackWidth': '1.33',
#   'SuperRange': '5.67',
#   'SuperSuperCharge': '4.56',
#   'SuperSpeed': nan,
#   'Health': {'1': '3600',
#    '2': '3780',
#    '3': '3960',
#    '4': '4140',
#    '5': '4320',
#    '6': '4500',
#    '7': '4680',
#    '8': '4860',
#    '9': '5040',
#    '10': '5220',
#    '11': '5400'},
#   'Attack': {'1': '520',
#    '2': '546',
#    '3': '572',
#    '4': '598',
#    '5': '624',
#    '6': '650',
#    '7': '676',
#    '8': '702',
#    '9': '728',
#    '10': '754',
#    '11': '780'}},
#  'EVE': {'Rarity': 'Chromatic',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '720',
#   'AttackRange': '9.33',
#   'AttackBullets': '3',
#   'Reload': '1.6',
#   'AttackSuperCharge': '11.2',
#   'AttackSpeed': '3500',
#   'AttackWidth': nan,
#   'SuperRange': '5',
#   'SuperSuperCharge': '2.5',
#   'SuperSpeed': nan,
#   'Health': {'1': '2900',
#    '2': '3045',
#    '3': '3190',
#    '4': '3335',
#    '5': '3480',
#    '6': '3625',
#    '7': '3770',
#    '8': '3915',
#    '9': '4060',
#    '10': '4205',
#    '11': '4350'},
#   'Attack': {'1': '400',
#    '2': '420',
#    '3': '440',
#    '4': '460',
#    '5': '480',
#    '6': '500',
#    '7': '520',
#    '8': '540',
#    '9': '560',
#    '10': '580',
#    '11': '600'}},
#  'FANG': {'Rarity': 'Chromatic',
#   'Class': 'Assassin',
#   'MovementSpeed': '770',
#   'AttackRange': '3',
#   'AttackBullets': '1',
#   'Reload': '1',
#   'AttackSuperCharge': '25',
#   'AttackSpeed': '4500',
#   'AttackWidth': '2',
#   'SuperRange': '9',
#   'SuperSuperCharge': '20',
#   'SuperSpeed': '4500',
#   'Health': {'1': '4300',
#    '2': '4515',
#    '3': '4730',
#    '4': '4945',
#    '5': '5160',
#    '6': '5375',
#    '7': '5590',
#    '8': '5805',
#    '9': '6020',
#    '10': '6235',
#    '11': '6450'},
#   'Attack': {'1': '1400',
#    '2': '1470',
#    '3': '1540',
#    '4': '1610',
#    '5': '1680',
#    '6': '1750',
#    '7': '1820',
#    '8': '1890',
#    '9': '1960',
#    '10': '2030',
#    '11': '2100'}},
#  'FRANK': {'Rarity': 'Epic',
#   'Class': 'Tank',
#   'MovementSpeed': '770',
#   'AttackRange': '6',
#   'AttackBullets': nan,
#   'Reload': '0.8',
#   'AttackSuperCharge': '37.2',
#   'AttackSpeed': '5000',
#   'AttackWidth': '1',
#   'SuperRange': '7',
#   'SuperSuperCharge': '37.2',
#   'SuperSpeed': '6000',
#   'Health': {'1': '7000',
#    '2': '7350',
#    '3': '7700',
#    '4': '8050',
#    '5': '8400',
#    '6': '8750',
#    '7': '9100',
#    '8': '9450',
#    '9': '9800',
#    '10': '10150',
#    '11': '10500'},
#   'Attack': {'1': '1240',
#    '2': '1302',
#    '3': '1364',
#    '4': '1426',
#    '5': '1488',
#    '6': '1550',
#    '7': '1612',
#    '8': '1674',
#    '9': '1736',
#    '10': '1798',
#    '11': '1860'}},
#  'GALE': {'Rarity': 'Chromatic',
#   'Class': 'Controller',
#   'MovementSpeed': '720',
#   'AttackRange': '8.33',
#   'AttackBullets': '6',
#   'Reload': '1.2',
#   'AttackSuperCharge': '6.67',
#   'AttackSpeed': '3000',
#   'AttackWidth': '2',
#   'SuperRange': '10',
#   'SuperSuperCharge': '10.2',
#   'SuperSpeed': '5000',
#   'Health': {'1': '3600',
#    '2': '3780',
#    '3': '3960',
#    '4': '4140',
#    '5': '4320',
#    '6': '4500',
#    '7': '4680',
#    '8': '4860',
#    '9': '5040',
#    '10': '5220',
#    '11': '5400'},
#   'Attack': {'1': '280',
#    '2': '294',
#    '3': '308',
#    '4': '322',
#    '5': '336',
#    '6': '350',
#    '7': '364',
#    '8': '378',
#    '9': '392',
#    '10': '406',
#    '11': '420'}},
#  'GENE': {'Rarity': 'Mythic',
#   'Class': 'Controller',
#   'MovementSpeed': '720',
#   'AttackRange': '5.67',
#   'AttackBullets': '1',
#   'Reload': '2',
#   'AttackSuperCharge': '25.2',
#   'AttackSpeed': '3200',
#   'AttackWidth': '1',
#   'SuperRange': '7.67',
#   'SuperSuperCharge': nan,
#   'SuperSpeed': '3200',
#   'Health': {'1': '3600',
#    '2': '3780',
#    '3': '3960',
#    '4': '4140',
#    '5': '4320',
#    '6': '4500',
#    '7': '4680',
#    '8': '4860',
#    '9': '5040',
#    '10': '5220',
#    '11': '5400'},
#   'Attack': {'1': '960',
#    '2': '1008',
#    '3': '1056',
#    '4': '1104',
#    '5': '1152',
#    '6': '1200',
#    '7': '1248',
#    '8': '1296',
#    '9': '1344',
#    '10': '1392',
#    '11': '1440'}},
#  'GRAY': {'Rarity': 'Mythic',
#   'Class': 'Support',
#   'MovementSpeed': '720',
#   'AttackRange': '9',
#   'AttackBullets': nan,
#   'Reload': '1.4',
#   'AttackSuperCharge': '25.2',
#   'AttackSpeed': '3804',
#   'AttackWidth': '0.33',
#   'SuperRange': '7',
#   'SuperSuperCharge': nan,
#   'SuperSpeed': nan,
#   'Health': {'1': '3300',
#    '2': '3465',
#    '3': '3630',
#    '4': '3795',
#    '5': '3960',
#    '6': '4125',
#    '7': '4290',
#    '8': '4455',
#    '9': '4620',
#    '10': '4785',
#    '11': '4950'},
#   'Attack': {'1': '1160',
#    '2': '1218',
#    '3': '1276',
#    '4': '1334',
#    '5': '1392',
#    '6': '1450',
#    '7': '1508',
#    '8': '1566',
#    '9': '1624',
#    '10': '1682',
#    '11': '1740'}},
#  'GRIFF': {'Rarity': 'Epic',
#   'Class': 'Controller',
#   'MovementSpeed': '720',
#   'AttackRange': '8.33',
#   'AttackBullets': '9',
#   'Reload': '1.7',
#   'AttackSuperCharge': '6.6',
#   'AttackSpeed': '3100',
#   'AttackWidth': '0.33',
#   'SuperRange': '9',
#   'SuperSuperCharge': nan,
#   'SuperSpeed': '3200',
#   'Health': {'1': '3400',
#    '2': '3570',
#    '3': '3740',
#    '4': '3910',
#    '5': '4080',
#    '6': '4250',
#    '7': '4420',
#    '8': '4590',
#    '9': '4760',
#    '10': '4930',
#    '11': '5100'},
#   'Attack': {'1': '260',
#    '2': '273',
#    '3': '286',
#    '4': '299',
#    '5': '312',
#    '6': '325',
#    '7': '338',
#    '8': '351',
#    '9': '364',
#    '10': '377',
#    '11': '390'}},
#  'GROM': {'Rarity': 'Epic',
#   'Class': 'Artillery',
#   'MovementSpeed': '720',
#   'AttackRange': '7.67',
#   'AttackBullets': '4',
#   'Reload': '2',
#   'AttackSuperCharge': '16.67',
#   'AttackSpeed': '840',
#   'AttackWidth': '0.83',
#   'SuperRange': '5.67',
#   'SuperSuperCharge': '20.98',
#   'SuperSpeed': '3000',
#   'Health': {'1': '3000',
#    '2': '3150',
#    '3': '3300',
#    '4': '3450',
#    '5': '3600',
#    '6': '3750',
#    '7': '3900',
#    '8': '4050',
#    '9': '4200',
#    '10': '4350',
#    '11': '4500'},
#   'Attack': {'1': '1060',
#    '2': '1113',
#    '3': '1166',
#    '4': '1219',
#    '5': '1272',
#    '6': '1325',
#    '7': '1378',
#    '8': '1431',
#    '9': '1484',
#    '10': '1537',
#    '11': '1590'}},
#  'GUS': {'Rarity': 'Super Rare',
#   'Class': 'Support',
#   'MovementSpeed': '720',
#   'AttackRange': '9.33',
#   'AttackBullets': nan,
#   'Reload': '1.5',
#   'AttackSuperCharge': '25',
#   'AttackSpeed': '4000',
#   'AttackWidth': '1',
#   'SuperRange': '9.33',
#   'SuperSuperCharge': nan,
#   'SuperSpeed': '3600',
#   'Health': {'1': '3200',
#    '2': '3360',
#    '3': '3520',
#    '4': '3680',
#    '5': '3840',
#    '6': '4000',
#    '7': '4160',
#    '8': '4320',
#    '9': '4480',
#    '10': '4640',
#    '11': '4800'},
#   'Attack': {'1': '940',
#    '2': '987',
#    '3': '1034',
#    '4': '1081',
#    '5': '1128',
#    '6': '1175',
#    '7': '1222',
#    '8': '1269',
#    '9': '1316',
#    '10': '1363',
#    '11': '1410'}},
#  'JACKY': {'Rarity': 'Super Rare',
#   'Class': 'Tank',
#   'MovementSpeed': '770',
#   'AttackRange': '3.33',
#   'AttackBullets': nan,
#   'Reload': '1.8',
#   'AttackSuperCharge': '25.28',
#   'AttackSpeed': nan,
#   'AttackWidth': nan,
#   'SuperRange': '5',
#   'SuperSuperCharge': nan,
#   'SuperSpeed': nan,
#   'Health': {'1': '5000',
#    '2': '5250',
#    '3': '5500',
#    '4': '5750',
#    '5': '6000',
#    '6': '6250',
#    '7': '6500',
#    '8': '6750',
#    '9': '7000',
#    '10': '7250',
#    '11': '7500'},
#   'Attack': {'1': '1240',
#    '2': '1302',
#    '3': '1364',
#    '4': '1426',
#    '5': '1488',
#    '6': '1550',
#    '7': '1612',
#    '8': '1674',
#    '9': '1736',
#    '10': '1798',
#    '11': '1860'}},
#  'JANET': {'Rarity': 'Chromatic',
#   'Class': 'Marksman',
#   'MovementSpeed': '720',
#   'AttackRange': '4',
#   'AttackBullets': nan,
#   'Reload': '1.5',
#   'AttackSuperCharge': '16.67',
#   'AttackSpeed': '3500',
#   'AttackWidth': nan,
#   'SuperRange': '2',
#   'SuperSuperCharge': '12.6',
#   'SuperSpeed': '1500',
#   'Health': {'1': '3400',
#    '2': '3570',
#    '3': '3740',
#    '4': '3910',
#    '5': '4080',
#    '6': '4250',
#    '7': '4420',
#    '8': '4590',
#    '9': '4760',
#    '10': '4930',
#    '11': '5100'},
#   'Attack': {'1': '1000',
#    '2': '1050',
#    '3': '1100',
#    '4': '1150',
#    '5': '1200',
#    '6': '1250',
#    '7': '1300',
#    '8': '1350',
#    '9': '1400',
#    '10': '1450',
#    '11': '1500'}},
#  'JESSIE': {'Rarity': 'Super Rare',
#   'Class': 'Controller',
#   'MovementSpeed': '720',
#   'AttackRange': '9',
#   'AttackBullets': nan,
#   'Reload': '1.8',
#   'AttackSuperCharge': '16.695',
#   'AttackSpeed': '2870',
#   'AttackWidth': '1',
#   'SuperRange': '5',
#   'SuperSuperCharge': '6.305',
#   'SuperSpeed': '1196',
#   'Health': {'1': '3000',
#    '2': '3150',
#    '3': '3300',
#    '4': '3450',
#    '5': '3600',
#    '6': '3750',
#    '7': '3900',
#    '8': '4050',
#    '9': '4200',
#    '10': '4350',
#    '11': '4500'},
#   'Attack': {'1': '1060',
#    '2': '1113',
#    '3': '1166',
#    '4': '1219',
#    '5': '1272',
#    '6': '1325',
#    '7': '1378',
#    '8': '1431',
#    '9': '1484',
#    '10': '1537',
#    '11': '1590'}},
#  'LEON': {'Rarity': 'Legendary',
#   'Class': 'Assassin',
#   'MovementSpeed': '820',
#   'AttackRange': '9.67',
#   'AttackBullets': '4',
#   'Reload': '1.9',
#   'AttackSuperCharge': 3.7875,
#   'AttackSpeed': '3500',
#   'AttackWidth': '0.67',
#   'SuperRange': nan,
#   'SuperSuperCharge': nan,
#   'SuperSpeed': nan,
#   'Health': {'1': '3200',
#    '2': '3360',
#    '3': '3520',
#    '4': '3680',
#    '5': '3840',
#    '6': '4000',
#    '7': '4160',
#    '8': '4320',
#    '9': '4480',
#    '10': '4640',
#    '11': '4800'},
#   'Attack': {'1': '480',
#    '2': '504',
#    '3': '528',
#    '4': '552',
#    '5': '576',
#    '6': '600',
#    '7': '624',
#    '8': '648',
#    '9': '672',
#    '10': '696',
#    '11': '720'}},
#  'LOLA': {'Rarity': 'Chromatic',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '720',
#   'AttackRange': '8.67',
#   'AttackBullets': '6',
#   'Reload': '1.5',
#   'AttackSuperCharge': '6.73',
#   'AttackSpeed': '4500',
#   'AttackWidth': '0.67',
#   'SuperRange': '4.33',
#   'SuperSuperCharge': '8.37',
#   'SuperSpeed': nan,
#   'Health': {'1': '3800',
#    '2': '3990',
#    '3': '4180',
#    '4': '4370',
#    '5': '4560',
#    '6': '4750',
#    '7': '4940',
#    '8': '5130',
#    '9': '5320',
#    '10': '5510',
#    '11': '5700'},
#   'Attack': {'1': '260',
#    '2': '273',
#    '3': '286',
#    '4': '299',
#    '5': '312',
#    '6': '325',
#    '7': '338',
#    '8': '351',
#    '9': '364',
#    '10': '377',
#    '11': '390'}},
#  'LOU': {'Rarity': 'Chromatic',
#   'Class': 'Controller',
#   'MovementSpeed': '720',
#   'AttackRange': '9.33',
#   'AttackBullets': '3',
#   'Reload': '1.3',
#   'AttackSuperCharge': '15.73',
#   'AttackSpeed': '4000',
#   'AttackWidth': '0.33',
#   'SuperRange': '7.67',
#   'SuperSuperCharge': '1',
#   'SuperSpeed': '1739',
#   'Health': {'1': '3200',
#    '2': '3360',
#    '3': '3520',
#    '4': '3680',
#    '5': '3840',
#    '6': '4000',
#    '7': '4160',
#    '8': '4320',
#    '9': '4480',
#    '10': '4640',
#    '11': '4800'},
#   'Attack': {'1': '440',
#    '2': '462',
#    '3': '484',
#    '4': '506',
#    '5': '528',
#    '6': '550',
#    '7': '572',
#    '8': '594',
#    '9': '616',
#    '10': '638',
#    '11': '660'}},
#  'MANDY': {'Rarity': 'Chromatic',
#   'Class': 'Marksman',
#   'MovementSpeed': '720',
#   'AttackRange': '9',
#   'AttackBullets': '1',
#   'Reload': '1.5',
#   'AttackSuperCharge': '20',
#   'AttackSpeed': '3500',
#   'AttackWidth': '0.67',
#   'SuperRange': '40',
#   'SuperSuperCharge': '50',
#   'SuperSpeed': '4200',
#   'Health': {'1': '2800',
#    '2': '2940',
#    '3': '3080',
#    '4': '3220',
#    '5': '3360',
#    '6': '3500',
#    '7': '3640',
#    '8': '3780',
#    '9': '3920',
#    '10': '4060',
#    '11': '4200'},
#   'Attack': {'1': '1200',
#    '2': '1260',
#    '3': '1320',
#    '4': '1380',
#    '5': '1440',
#    '6': '1500',
#    '7': '1560',
#    '8': '1620',
#    '9': '1680',
#    '10': '1740',
#    '11': '1800'}},
#  'MAX': {'Rarity': 'Mythic',
#   'Class': 'Support',
#   'MovementSpeed': '820',
#   'AttackRange': '8.33',
#   'AttackBullets': '4',
#   'Reload': '1.3',
#   'AttackSuperCharge': '7.88',
#   'AttackSpeed': '4000',
#   'AttackWidth': '0.33',
#   'SuperRange': '4',
#   'SuperSuperCharge': nan,
#   'SuperSpeed': nan,
#   'Health': {'1': '3200',
#    '2': '3360',
#    '3': '3520',
#    '4': '3680',
#    '5': '3840',
#    '6': '4000',
#    '7': '4160',
#    '8': '4320',
#    '9': '4480',
#    '10': '4640',
#    '11': '4800'},
#   'Attack': {'1': '340',
#    '2': '357',
#    '3': '374',
#    '4': '391',
#    '5': '408',
#    '6': '425',
#    '7': '442',
#    '8': '459',
#    '9': '476',
#    '10': '493',
#    '11': '510'}},
#  'MEG': {'Rarity': 'Legendary',
#   'Class': 'Tank',
#   'MovementSpeed': '770',
#   'AttackRange': '9',
#   'AttackBullets': '2',
#   'Reload': '1.3',
#   'AttackSuperCharge': '14.28',
#   'AttackSpeed': '4000',
#   'AttackWidth': '1',
#   'SuperRange': '4.33',
#   'SuperSuperCharge': nan,
#   'SuperSpeed': nan,
#   'Health': {'1': '2300',
#    '2': '2415',
#    '3': '2530',
#    '4': '2645',
#    '5': '2760',
#    '6': '2875',
#    '7': '2990',
#    '8': '3105',
#    '9': '3220',
#    '10': '3335',
#    '11': '3450'},
#   'Attack': {'1': '300',
#    '2': '315',
#    '3': '330',
#    '4': '345',
#    '5': '360',
#    '6': '375',
#    '7': '390',
#    '8': '405',
#    '9': '420',
#    '10': '435',
#    '11': '450'}},
#  'MORTIS': {'Rarity': 'Mythic',
#   'Class': 'Assassin',
#   'MovementSpeed': '820',
#   'AttackRange': '2.67',
#   'AttackBullets': nan,
#   'Reload': '2.4',
#   'AttackSuperCharge': '20.025',
#   'AttackSpeed': nan,
#   'AttackWidth': nan,
#   'SuperRange': '10',
#   'SuperSuperCharge': '30.15',
#   'SuperSpeed': '2718',
#   'Health': {'1': '3800',
#    '2': '3990',
#    '3': '4180',
#    '4': '4370',
#    '5': '4560',
#    '6': '4750',
#    '7': '4940',
#    '8': '5130',
#    '9': '5320',
#    '10': '5510',
#    '11': '5700'},
#   'Attack': {'1': '900',
#    '2': '945',
#    '3': '990',
#    '4': '1035',
#    '5': '1080',
#    '6': '1125',
#    '7': '1170',
#    '8': '1215',
#    '9': '1260',
#    '10': '1305',
#    '11': '1350'}},
#  'MR. P': {'Rarity': 'Mythic',
#   'Class': 'Controller',
#   'MovementSpeed': '720',
#   'AttackRange': '7',
#   'AttackBullets': nan,
#   'Reload': '1.6',
#   'AttackSuperCharge': '16.74',
#   'AttackSpeed': '3000',
#   'AttackWidth': '1.33',
#   'SuperRange': '5',
#   'SuperSuperCharge': '5.59',
#   'SuperSpeed': '1196',
#   'Health': {'1': '3000',
#    '2': '3150',
#    '3': '3300',
#    '4': '3450',
#    '5': '3600',
#    '6': '3750',
#    '7': '3900',
#    '8': '4050',
#    '9': '4200',
#    '10': '4350',
#    '11': '4500'},
#   'Attack': {'1': '760',
#    '2': '798',
#    '3': '836',
#    '4': '874',
#    '5': '912',
#    '6': '950',
#    '7': '988',
#    '8': '1026',
#    '9': '1064',
#    '10': '1102',
#    '11': '1140'}},
#  'NANI': {'Rarity': 'Epic',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '720',
#   'AttackRange': '8.67',
#   'AttackBullets': '3',
#   'Reload': '1.8',
#   'AttackSuperCharge': '17.5',
#   'AttackSpeed': '4000',
#   'AttackWidth': '0.27',
#   'SuperRange': '3.33',
#   'SuperSuperCharge': '22.5',
#   'SuperSpeed': '2500',
#   'Health': {'1': '2600',
#    '2': '2730',
#    '3': '2860',
#    '4': '2990',
#    '5': '3120',
#    '6': '3250',
#    '7': '3380',
#    '8': '3510',
#    '9': '3640',
#    '10': '3770',
#    '11': '3900'},
#   'Attack': {'1': '700',
#    '2': '735',
#    '3': '770',
#    '4': '805',
#    '5': '840',
#    '6': '875',
#    '7': '910',
#    '8': '945',
#    '9': '980',
#    '10': '1015',
#    '11': '1050'}},
#  'NITA': {'Rarity': 'Rare',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '720',
#   'AttackRange': '6',
#   'AttackBullets': nan,
#   'Reload': '1.1',
#   'AttackSuperCharge': '20',
#   'AttackSpeed': '2718',
#   'AttackWidth': '1.67',
#   'SuperRange': '5',
#   'SuperSuperCharge': '10',
#   'SuperSpeed': '1196',
#   'Health': {'1': '4000',
#    '2': '4200',
#    '3': '4400',
#    '4': '4600',
#    '5': '4800',
#    '6': '5000',
#    '7': '5200',
#    '8': '5400',
#    '9': '5600',
#    '10': '5800',
#    '11': '6000'},
#   'Attack': {'1': '960',
#    '2': '1008',
#    '3': '1056',
#    '4': '1104',
#    '5': '1152',
#    '6': '1200',
#    '7': '1248',
#    '8': '1296',
#    '9': '1344',
#    '10': '1392',
#    '11': '1440'}},
#  'OTIS': {'Rarity': 'Chromatic',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '720',
#   'AttackRange': '9',
#   'AttackBullets': '3',
#   'Reload': '1.5',
#   'AttackSuperCharge': '8.25',
#   'AttackSpeed': '3600',
#   'AttackWidth': '0.67',
#   'SuperRange': '9',
#   'SuperSuperCharge': '8.33',
#   'SuperSpeed': '3200',
#   'Health': {'1': '3200',
#    '2': '3360',
#    '3': '3520',
#    '4': '3680',
#    '5': '3840',
#    '6': '4000',
#    '7': '4160',
#    '8': '4320',
#    '9': '4480',
#    '10': '4640',
#    '11': '4800'},
#   'Attack': {'1': '440',
#    '2': '462',
#    '3': '484',
#    '4': '506',
#    '5': '528',
#    '6': '550',
#    '7': '572',
#    '8': '594',
#    '9': '616',
#    '10': '638',
#    '11': '660'}},
#  'PAM': {'Rarity': 'Epic',
#   'Class': 'Support',
#   'MovementSpeed': '720',
#   'AttackRange': '9',
#   'AttackBullets': '9',
#   'Reload': '1.3',
#   'AttackSuperCharge': '6.825',
#   'AttackSpeed': '4130',
#   'AttackWidth': '0.33',
#   'SuperRange': '5',
#   'SuperSuperCharge': nan,
#   'SuperSpeed': '1196',
#   'Health': {'1': '4800',
#    '2': '5040',
#    '3': '5280',
#    '4': '5520',
#    '5': '5760',
#    '6': '6000',
#    '7': '6240',
#    '8': '6480',
#    '9': '6720',
#    '10': '6960',
#    '11': '7200'},
#   'Attack': {'1': '260',
#    '2': '273',
#    '3': '286',
#    '4': '299',
#    '5': '312',
#    '6': '325',
#    '7': '338',
#    '8': '351',
#    '9': '364',
#    '10': '377',
#    '11': '390'}},
#  'PENNY': {'Rarity': 'Super Rare',
#   'Class': 'Artillery',
#   'MovementSpeed': '720',
#   'AttackRange': '8',
#   'AttackBullets': '4',
#   'Reload': '2',
#   'AttackSuperCharge': '21.855',
#   'AttackSpeed': '3400',
#   'AttackWidth': '1',
#   'SuperRange': '5',
#   'SuperSuperCharge': '30',
#   'SuperSpeed': '1196',
#   'Health': {'1': '3600',
#    '2': '3780',
#    '3': '3960',
#    '4': '4140',
#    '5': '4320',
#    '6': '4500',
#    '7': '4680',
#    '8': '4860',
#    '9': '5040',
#    '10': '5220',
#    '11': '5400'},
#   'Attack': {'1': '940',
#    '2': '987',
#    '3': '1034',
#    '4': '1081',
#    '5': '1128',
#    '6': '1175',
#    '7': '1222',
#    '8': '1269',
#    '9': '1316',
#    '10': '1363',
#    '11': '1410'}},
#  'PIPER': {'Rarity': 'Epic',
#   'Class': 'Marksman',
#   'MovementSpeed': '720',
#   'AttackRange': '10',
#   'AttackBullets': nan,
#   'Reload': '2.3',
#   'AttackSuperCharge': 14.186,
#   'AttackSpeed': '4000',
#   'AttackWidth': '0.67',
#   'SuperRange': '8.67',
#   'SuperSuperCharge': '20.25',
#   'SuperSpeed': nan,
#   'Health': {'1': '2400',
#    '2': '2520',
#    '3': '2640',
#    '4': '2760',
#    '5': '2880',
#    '6': '3000',
#    '7': '3120',
#    '8': '3240',
#    '9': '3360',
#    '10': '3480',
#    '11': '3600'},
#   'Attack': {'1': '350',
#    '2': '367',
#    '3': '384',
#    '4': '401',
#    '5': '418',
#    '6': '435',
#    '7': '452',
#    '8': '469',
#    '9': '486',
#    '10': '503',
#    '11': '520'}},
#  'POCO': {'Rarity': 'Rare',
#   'Class': 'Support',
#   'MovementSpeed': '720',
#   'AttackRange': '7',
#   'AttackBullets': nan,
#   'Reload': '1.6',
#   'AttackSuperCharge': '21',
#   'AttackSpeed': '2500',
#   'AttackWidth': nan,
#   'SuperRange': '9.33',
#   'SuperSuperCharge': nan,
#   'SuperSpeed': '5000',
#   'Health': {'1': '3700',
#    '2': '3885',
#    '3': '4070',
#    '4': '4255',
#    '5': '4440',
#    '6': '4625',
#    '7': '4810',
#    '8': '4995',
#    '9': '5180',
#    '10': '5365',
#    '11': '5550'},
#   'Attack': {'1': '760',
#    '2': '798',
#    '3': '836',
#    '4': '874',
#    '5': '912',
#    '6': '950',
#    '7': '988',
#    '8': '1026',
#    '9': '1064',
#    '10': '1102',
#    '11': '1140'}},
#  'R-T': {'Rarity': 'Chromatic',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '720',
#   'AttackRange': '9.33',
#   'AttackBullets': '1',
#   'Reload': nan,
#   'AttackSuperCharge': '26.1',
#   'AttackSpeed': nan,
#   'AttackWidth': nan,
#   'SuperRange': nan,
#   'SuperSuperCharge': nan,
#   'SuperSpeed': 'Instant',
#   'Health': {'1': '4100',
#    '2': '4305',
#    '3': '4510',
#    '4': '4715',
#    '5': '4920',
#    '6': '5125',
#    '7': '5330',
#    '8': '5535',
#    '9': '5740',
#    '10': '5945',
#    '11': '6150'},
#   'Attack': {'1': '700',
#    '2': '735',
#    '3': '770',
#    '4': '805',
#    '5': '840',
#    '6': '875',
#    '7': '910',
#    '8': '945',
#    '9': '980',
#    '10': '1015',
#    '11': '1050'}},
#  'RICO': {'Rarity': 'Super Rare',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '720',
#   'AttackRange': '9.67',
#   'AttackBullets': '5',
#   'Reload': '1.2',
#   'AttackSuperCharge': '8.4',
#   'AttackSpeed': '3478',
#   'AttackWidth': '0.67',
#   'SuperRange': '13.33',
#   'SuperSuperCharge': '8.4',
#   'SuperSpeed': '4891',
#   'Health': {'1': '2800',
#    '2': '2940',
#    '3': '3080',
#    '4': '3220',
#    '5': '3360',
#    '6': '3500',
#    '7': '3640',
#    '8': '3780',
#    '9': '3920',
#    '10': '4060',
#    '11': '4200'},
#   'Attack': {'1': '320',
#    '2': '336',
#    '3': '352',
#    '4': '368',
#    '5': '384',
#    '6': '400',
#    '7': '416',
#    '8': '432',
#    '9': '448',
#    '10': '464',
#    '11': '480'}},
#  'ROSA': {'Rarity': 'Rare',
#   'Class': 'Tank',
#   'MovementSpeed': '770',
#   'AttackRange': '3.67',
#   'AttackBullets': '3',
#   'Reload': '1',
#   'AttackSuperCharge': '11.155',
#   'AttackSpeed': '5000',
#   'AttackWidth': '1',
#   'SuperRange': nan,
#   'SuperSuperCharge': nan,
#   'SuperSpeed': nan,
#   'Health': {'1': '5400',
#    '2': '5670',
#    '3': '5940',
#    '4': '6210',
#    '5': '6480',
#    '6': '6750',
#    '7': '7020',
#    '8': '7290',
#    '9': '7560',
#    '10': '7830',
#    '11': '8100'},
#   'Attack': {'1': '460',
#    '2': '483',
#    '3': '506',
#    '4': '529',
#    '5': '552',
#    '6': '575',
#    '7': '598',
#    '8': '621',
#    '9': '644',
#    '10': '667',
#    '11': '690'}},
#  'RUFFS': {'Rarity': 'Chromatic',
#   'Class': 'Support',
#   'MovementSpeed': '720',
#   'AttackRange': '9',
#   'AttackBullets': '2',
#   'Reload': '1.4',
#   'AttackSuperCharge': '15.25',
#   'AttackSpeed': '3500',
#   'AttackWidth': '0.47',
#   'SuperRange': '7.67',
#   'SuperSuperCharge': '33.5',
#   'SuperSpeed': '1700',
#   'Health': {'1': '2800',
#    '2': '2940',
#    '3': '3080',
#    '4': '3220',
#    '5': '3360',
#    '6': '3500',
#    '7': '3640',
#    '8': '3780',
#    '9': '3920',
#    '10': '4060',
#    '11': '4200'},
#   'Attack': {'1': '560',
#    '2': '588',
#    '3': '616',
#    '4': '644',
#    '5': '672',
#    '6': '700',
#    '7': '728',
#    '8': '756',
#    '9': '784',
#    '10': '812',
#    '11': '840'}},
#  'SAM': {'Rarity': 'Chromatic',
#   'Class': 'Assassin',
#   'MovementSpeed': '770',
#   'AttackRange': '3',
#   'AttackBullets': '2',
#   'Reload': '1.6',
#   'AttackSuperCharge': '10',
#   'AttackSpeed': '5000',
#   'AttackWidth': nan,
#   'SuperRange': '8.67',
#   'SuperSuperCharge': '33.33',
#   'SuperSpeed': '2900',
#   'Health': {'1': '5400',
#    '2': '5670',
#    '3': '5940',
#    '4': '6210',
#    '5': '6480',
#    '6': '6750',
#    '7': '7020',
#    '8': '7290',
#    '9': '7560',
#    '10': '7830',
#    '11': '8100'},
#   'Attack': {'1': '800',
#    '2': '840',
#    '3': '880',
#    '4': '920',
#    '5': '960',
#    '6': '1000',
#    '7': '1040',
#    '8': '1080',
#    '9': '1120',
#    '10': '1160',
#    '11': '1200'}},
#  'SANDY': {'Rarity': 'Legendary',
#   'Class': 'Controller',
#   'MovementSpeed': '770',
#   'AttackRange': '6',
#   'AttackBullets': nan,
#   'Reload': '1.8',
#   'AttackSuperCharge': '14.3',
#   'AttackSpeed': '3500',
#   'AttackWidth': '1.33',
#   'SuperRange': '7.33',
#   'SuperSuperCharge': nan,
#   'SuperSpeed': '2000',
#   'Health': {'1': '3800',
#    '2': '3990',
#    '3': '4180',
#    '4': '4370',
#    '5': '4560',
#    '6': '4750',
#    '7': '4940',
#    '8': '5130',
#    '9': '5320',
#    '10': '5510',
#    '11': '5700'},
#   'Attack': {'1': '900',
#    '2': '945',
#    '3': '990',
#    '4': '1035',
#    '5': '1080',
#    '6': '1125',
#    '7': '1170',
#    '8': '1215',
#    '9': '1260',
#    '10': '1305',
#    '11': '1350'}},
#  'SHELLY': {'Rarity': 'Starting Brawler',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '720',
#   'AttackRange': '7.67',
#   'AttackBullets': '5',
#   'Reload': '1.5',
#   'AttackSuperCharge': '10.05',
#   'AttackSpeed': '3100',
#   'AttackWidth': nan,
#   'SuperRange': '7.67',
#   'SuperSuperCharge': '8.96',
#   'SuperSpeed': '4130',
#   'Health': {'1': '3800',
#    '2': '3990',
#    '3': '4180',
#    '4': '4370',
#    '5': '4560',
#    '6': '4750',
#    '7': '4940',
#    '8': '5130',
#    '9': '5320',
#    '10': '5510',
#    '11': '5700'},
#   'Attack': {'1': '300',
#    '2': '315',
#    '3': '330',
#    '4': '345',
#    '5': '360',
#    '6': '375',
#    '7': '390',
#    '8': '405',
#    '9': '420',
#    '10': '435',
#    '11': '450'}},
#  'SPIKE': {'Rarity': 'Legendary',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '720',
#   'AttackRange': '7.67',
#   'AttackBullets': '7',
#   'Reload': '2',
#   'AttackSuperCharge': '14.42',
#   'AttackSpeed': '2174',
#   'AttackWidth': '1',
#   'SuperRange': '7.67',
#   'SuperSuperCharge': '12.5',
#   'SuperSpeed': '1739',
#   'Health': {'1': '2400',
#    '2': '2520',
#    '3': '2640',
#    '4': '2760',
#    '5': '2880',
#    '6': '3000',
#    '7': '3120',
#    '8': '3240',
#    '9': '3360',
#    '10': '3480',
#    '11': '3600'},
#   'Attack': {'1': '560',
#    '2': '588',
#    '3': '616',
#    '4': '644',
#    '5': '672',
#    '6': '700',
#    '7': '728',
#    '8': '756',
#    '9': '784',
#    '10': '812',
#    '11': '840'}},
#  'SPROUT': {'Rarity': 'Mythic',
#   'Class': 'Artillery',
#   'MovementSpeed': '720',
#   'AttackRange': '5',
#   'AttackBullets': nan,
#   'Reload': '1.7',
#   'AttackSuperCharge': '20.58',
#   'AttackSpeed': '1700',
#   'AttackWidth': '1',
#   'SuperRange': '7.67',
#   'SuperSuperCharge': nan,
#   'SuperSpeed': '1739',
#   'Health': {'1': '3000',
#    '2': '3150',
#    '3': '3300',
#    '4': '3450',
#    '5': '3600',
#    '6': '3750',
#    '7': '3900',
#    '8': '4050',
#    '9': '4200',
#    '10': '4350',
#    '11': '4500'},
#   'Attack': {'1': '980',
#    '2': '1029',
#    '3': '1078',
#    '4': '1127',
#    '5': '1176',
#    '6': '1225',
#    '7': '1274',
#    '8': '1323',
#    '9': '1372',
#    '10': '1421',
#    '11': '1470'}},
#  'SQUEAK': {'Rarity': 'Mythic',
#   'Class': 'Controller',
#   'MovementSpeed': '720',
#   'AttackRange': '7.67',
#   'AttackBullets': nan,
#   'Reload': '2.1',
#   'AttackSuperCharge': '25',
#   'AttackSpeed': '4000',
#   'AttackWidth': '0.33',
#   'SuperRange': '8.33',
#   'SuperSuperCharge': '12.5',
#   'SuperSpeed': '1600',
#   'Health': {'1': '3600',
#    '2': '3780',
#    '3': '3960',
#    '4': '4140',
#    '5': '4320',
#    '6': '4500',
#    '7': '4680',
#    '8': '4860',
#    '9': '5040',
#    '10': '5220',
#    '11': '5400'},
#   'Attack': {'1': '1080',
#    '2': '1134',
#    '3': '1188',
#    '4': '1242',
#    '5': '1296',
#    '6': '1350',
#    '7': '1404',
#    '8': '1458',
#    '9': '1512',
#    '10': '1566',
#    '11': '1620'}},
#  'STU': {'Rarity': 'Epic',
#   'Class': 'Assassin',
#   'MovementSpeed': '720',
#   'AttackRange': '7.67',
#   'AttackBullets': '2',
#   'Reload': '1.5',
#   'AttackSuperCharge': '100',
#   'AttackSpeed': '3300',
#   'AttackWidth': '1',
#   'SuperRange': '2.33',
#   'SuperSuperCharge': nan,
#   'SuperSpeed': nan,
#   'Health': {'1': '2900',
#    '2': '3045',
#    '3': '3190',
#    '4': '3335',
#    '5': '3480',
#    '6': '3625',
#    '7': '3770',
#    '8': '3915',
#    '9': '4060',
#    '10': '4205',
#    '11': '4350'},
#   'Attack': {'1': '540',
#    '2': '567',
#    '3': '594',
#    '4': '621',
#    '5': '648',
#    '6': '675',
#    '7': '702',
#    '8': '729',
#    '9': '756',
#    '10': '783',
#    '11': '810'}},
#  'SURGE': {'Rarity': 'Chromatic',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '650',
#   'AttackRange': '6.67',
#   'AttackBullets': nan,
#   'Reload': '2',
#   'AttackSuperCharge': '35.4',
#   'AttackSpeed': '3500',
#   'AttackWidth': '1',
#   'SuperRange': '2.67',
#   'SuperSuperCharge': '17',
#   'SuperSpeed': nan,
#   'Health': {'1': '2800',
#    '2': '2940',
#    '3': '3080',
#    '4': '3220',
#    '5': '3360',
#    '6': '3500',
#    '7': '3640',
#    '8': '3780',
#    '9': '3920',
#    '10': '4060',
#    '11': '4200'},
#   'Attack': {'1': '1180',
#    '2': '1239',
#    '3': '1298',
#    '4': '1357',
#    '5': '1416',
#    '6': '1475',
#    '7': '1534',
#    '8': '1593',
#    '9': '1652',
#    '10': '1711',
#    '11': '1770'}},
#  'TARA': {'Rarity': 'Mythic',
#   'Class': 'Damage Dealer',
#   'MovementSpeed': '720',
#   'AttackRange': '8',
#   'AttackBullets': '3',
#   'Reload': '2',
#   'AttackSuperCharge': '8.395',
#   'AttackSpeed': '3152',
#   'AttackWidth': '0.67',
#   'SuperRange': '6.67',
#   'SuperSuperCharge': '18',
#   'SuperSpeed': '1522',
#   'Health': {'1': '3200',
#    '2': '3360',
#    '3': '3520',
#    '4': '3680',
#    '5': '3840',
#    '6': '4000',
#    '7': '4160',
#    '8': '4320',
#    '9': '4480',
#    '10': '4640',
#    '11': '4800'},
#   'Attack': {'1': '440',
#    '2': '462',
#    '3': '484',
#    '4': '506',
#    '5': '528',
#    '6': '550',
#    '7': '572',
#    '8': '594',
#    '9': '616',
#    '10': '638',
#    '11': '660'}},
#  'TICK': {'Rarity': 'Super Rare',
#   'Class': 'Artillery',
#   'MovementSpeed': '720',
#   'AttackRange': '8.67',
#   'AttackBullets': '3',
#   'Reload': '2.3',
#   'AttackSuperCharge': '17.6',
#   'AttackSpeed': '2000',
#   'AttackWidth': nan,
#   'SuperRange': '3.33',
#   'SuperSuperCharge': '35',
#   'SuperSpeed': '1196',
#   'Health': {'1': '2200',
#    '2': '2310',
#    '3': '2420',
#    '4': '2530',
#    '5': '2640',
#    '6': '2750',
#    '7': '2860',
#    '8': '2970',
#    '9': '3080',
#    '10': '3190',
#    '11': '3300'},
#   'Attack': {'1': '640',
#    '2': '672',
#    '3': '704',
#    '4': '736',
#    '5': '768',
#    '6': '800',
#    '7': '832',
#    '8': '864',
#    '9': '896',
#    '10': '928',
#    '11': '960'}},
#  'WILLOW': {'Rarity': 'Mythic',
#   'Class': 'Controller',
#   'MovementSpeed': '720',
#   'AttackRange': nan,
#   'AttackBullets': '1',
#   'Reload': nan,
#   'AttackSuperCharge': '6.67',
#   'AttackSpeed': nan,
#   'AttackWidth': nan,
#   'SuperRange': nan,
#   'SuperSuperCharge': nan,
#   'SuperSpeed': nan,
#   'Health': {'1': '2500',
#    '2': '2625',
#    '3': '2750',
#    '4': '2875',
#    '5': '3000',
#    '6': '3125',
#    '7': '3250',
#    '8': '3375',
#    '9': '3500',
#    '10': '3625',
#    '11': '3750'},
#   'Attack': {'1': '400',
#    '2': '420',
#    '3': '440',
#    '4': '460',
#    '5': '480',
#    '6': '500',
#    '7': '520',
#    '8': '540',
#    '9': '560',
#    '10': '580',
#    '11': '600'}}}

# %%
import json
with open("./data/brawlerInfo.json", "w") as outfile:
    json.dump(brawlerDict, outfile)

# %% [markdown]
# ## Exporting Data to S3

# %%
# !aws s3 ls
# Out:
# 2023-02-13 13:14:50 si699-mj199-bucket

# %%
import time
date_string = time.strftime("%Y%m%d")

import boto3
s3client = boto3.client('s3')
s3client.upload_file('./data/brawlerInfo.json',  'si699-mj199-bucket', f'data/{date_string}/brawlerInfo.json')

# %% [markdown]
# ## Optional: Loading Data to AWS RDS (Database)

# %%
# brawler_info_df = pd.DataFrame(brawlerDict).T.iloc[:,:-2]
# brawler_info_df = brawler_info_df.reset_index()
# brawler_info_df = brawler_info_df.rename(columns = {'index':'name'})
# brawler_info_df['load_timestamp'] = pd.Timestamp.now()
# for col in list(brawler_info_df.columns)[3:-1]:
#     brawler_info_df[f'{col}'] = brawler_info_df[f'{col}'].astype(float)
# brawler_info_df
# Out:
#       name      Rarity          Class  MovementSpeed  AttackRange  \
# 0    8-BIT  Super Rare  Damage Dealer          580.0        10.00
# 1    AMBER   Legendary  Damage Dealer          720.0         8.33
# 2      ASH   Chromatic           Tank          720.0         4.67
# 3   BARLEY        Rare  Damage Dealer          720.0         7.33
# 4      BEA        Epic  Damage Dealer          720.0        10.00
# ..     ...         ...            ...            ...          ...
# 59  SQUEAK      Mythic  Damage Dealer          720.0         7.67
# 60     STU        Epic       Assassin          720.0         7.67
# 61   SURGE   Chromatic  Damage Dealer          650.0         6.67
# 62    TARA      Mythic  Damage Dealer          720.0         8.00
# 63    TICK  Super Rare  Damage Dealer          720.0         8.67
#
#     AttackBullets  Reload  AttackSuperCharge  AttackSpeed  AttackWidth  \
# 0             6.0    1.50              8.480       4500.0         0.33
# 1            40.0    0.22              4.550       3500.0         1.33
# 2             NaN    1.40             16.800       5000.0         1.67
# 3             NaN    2.00             17.500       1750.0          NaN
# 4             NaN    0.90             35.600       3255.0         1.00
# ..            ...     ...                ...          ...          ...
# 59            NaN    2.10             25.000       4000.0         0.33
# 60            2.0    1.50            100.000       3300.0         1.00
# 61            NaN    2.00             35.400       3500.0         1.00
# 62            3.0    2.00              8.395       3152.0         0.67
# 63            3.0    2.30             17.600       2000.0          NaN
#
#     SuperRange  SuperSuperCharge  SuperSpeed             load_timestamp
# 0         5.00               NaN      1196.0 2023-02-24 09:29:46.409412
# 1         7.33              6.36      1750.0 2023-02-24 09:29:46.409412
# 2         5.00              3.75      1196.0 2023-02-24 09:29:46.409412
# 3         9.33             12.58      1504.0 2023-02-24 09:29:46.409412
# 4         9.00              2.50      2500.0 2023-02-24 09:29:46.409412
# ..         ...               ...         ...                        ...
# 59        8.33             12.50      1600.0 2023-02-24 09:29:46.409412
# 60        2.33               NaN         NaN 2023-02-24 09:29:46.409412
# 61        2.67             17.00         NaN 2023-02-24 09:29:46.409412
# 62        6.67             18.00      1522.0 2023-02-24 09:29:46.409412
# 63        3.33             35.00      1196.0 2023-02-24 09:29:46.409412
#
# [64 rows x 14 columns]

# %%
# health_attack_df = pd.DataFrame(brawlerDict).T.iloc[:,-2:]
# health_attack_df = health_attack_df.reset_index()
# health_attack_df = health_attack_df.rename(columns = {'index':'name'})

# temp = pd.DataFrame({'power': health_attack_df['Health'].apply(lambda x: list(x.keys())).tolist(), 
#                      'Health': health_attack_df['Health'].apply(lambda x: list(x.values())).tolist(),
#                      'Attack': health_attack_df['Attack'].apply(lambda x: list(x.values())).tolist()})

# health_attack_df = health_attack_df[['name']].join(temp).apply(pd.Series.explode)
# health_attack_df['load_timestamp'] = pd.Timestamp.now()
# health_attack_df['power'] = health_attack_df['power'].astype('int64')
# health_attack_df['Health'] = health_attack_df['Health'].astype('float')
# health_attack_df['Attack'] = health_attack_df['Attack'].astype('float')
# health_attack_df
# Out:
#      name  power  Health  Attack             load_timestamp
# 0   8-BIT      1  4800.0   320.0 2023-02-24 09:29:46.458710
# 0   8-BIT      2  5040.0   336.0 2023-02-24 09:29:46.458710
# 0   8-BIT      3  5280.0   352.0 2023-02-24 09:29:46.458710
# 0   8-BIT      4  5520.0   368.0 2023-02-24 09:29:46.458710
# 0   8-BIT      5  5760.0   384.0 2023-02-24 09:29:46.458710
# ..    ...    ...     ...     ...                        ...
# 63   TICK      7  2860.0   832.0 2023-02-24 09:29:46.458710
# 63   TICK      8  2970.0   864.0 2023-02-24 09:29:46.458710
# 63   TICK      9  3080.0   896.0 2023-02-24 09:29:46.458710
# 63   TICK     10  3190.0   928.0 2023-02-24 09:29:46.458710
# 63   TICK     11  3300.0   960.0 2023-02-24 09:29:46.458710
#
# [704 rows x 5 columns]

# %%
# import psycopg2
# import psycopg2.extras as extras
# from sqlalchemy import create_engine

# %%
# PGHOST = 'mj199-database.cfk5zj0ywdiy.us-east-1.rds.amazonaws.com'
# PGDATABASE = 'brawl_stars_db'
# PGUSER = 'postgres'
# PGPASSWORD = 'mj199mj199'

# %%
# sa_conn_string = f'postgresql://{PGUSER}:{PGPASSWORD}@{PGHOST}/{PGDATABASE}'
# engine = create_engine(sa_conn_string)
# sa_conn = engine.connect()

# %%
# def connect():
    
#     # Set up a connection to the postgres server.
#     conn_string = "host="+ PGHOST +" port="+ "5432" +" dbname="+ PGDATABASE +" user=" + PGUSER \
#                   +" password="+ PGPASSWORD
    
#     conn = psycopg2.connect(conn_string)
#     print("Connected!")

#     # Create a cursor object
#     cursor = conn.cursor()
    
#     return conn, cursor

# %%
# conn, cursor = connect()
# Out:
# Connected!

# %%
# # Creating brawler_info table
# brawler_info_df.to_sql('brawler_info', con = engine, if_exists = 'append', index=False)
# sql='''select * from "brawler_info";'''

# # Execute SQL Command and commit to DB
# cursor.execute(sql)
# conn.commit()

# %%
## cursor.execute('''drop table "brawler_info"''')
## conn.commit()

# %%
# # Creating brawler_health_attack table
# health_attack_df.to_sql('brawler_health_attack', con = engine, if_exists = 'append', index=False)
# sql='''select * from "brawler_health_attack";'''

# # Execute SQL Command and commit to DB
# cursor.execute(sql)
# conn.commit()

# %%
## cursor.execute('''drop table "brawler_health_attack"''')
## conn.commit()
